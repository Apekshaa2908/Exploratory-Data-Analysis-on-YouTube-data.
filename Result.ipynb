# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('youtube_dislike_dataset.csv')

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
# Top 5 records
df.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
#Bottom 5
df.tail(5)
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
df.dtypes
# Out:
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# published_at     object
# view_count        int64
# likes             int64
# dislikes          int64
# comment_count     int64
# tags             object
# description      object
# comments         object
# dtype: object

# %% [markdown]
# ## Inference:view_count,likes,dislikes,comment_count are int datatypes wheras all the other are object datatypes

# %%
df.shape
# Out:
# (37422, 12)

# %% [markdown]
# 3. Check for the Percentage of the missing values and drop or impute them.

# %%
df.isnull().sum()*100/len(df)
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %% [markdown]
# ## Percentage of missing values=0.42%

# %%
df['comments'].dropna(inplace=True)

# %% [markdown]
# ## We drop the values in the comments

# %% [markdown]
# 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
df.describe(include='all')
# Out:
# C:\Users\Apekshaa\AppData\Local\Temp\ipykernel_14864\2884002236.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
# first           NaN    NaN                       NaN                  NaN
# last            NaN    NaN                       NaN                  NaN
# mean            NaN    NaN                       NaN                  NaN
# ...

# %% [markdown]
# ## Numerical data: video_id,title,Channel_id,channel_title,published_at,tags,description,comments,published_month
# ## Statistical data: view_count,likes,dislikes,comment_count
#
# ## The numerical data do not have statistical summary so count alone can be determined
# ## The mean,std,max,min and quartiles are identified for the statistical data

# %% [markdown]
# 5. Convert datatype of column published_at from object to pandas datetime.

# %%
df['published_at'] = pd.to_datetime(df['published_at'])

# %%
df['published_at']
# Out:
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37422, dtype: datetime64[ns]

# %% [markdown]
# 6. Create a new column as 'published_month' using the column published_at (display the months only

# %%
df['published_month'] =df['published_at'].dt.strftime('%m')
df[['published_month']]
# Out:
#       published_month
# 0                  07
# 1                  06
# 2                  09
# 3                  03
# 4                  12
# ...               ...
# 37417              02
# 37418              01
# 37419              06
# 37420              10
# 37421              05
#
# [37422 rows x 1 columns]

# %% [markdown]
# 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'
# and so on.....

# %%
df['published_month'] =df['published_at'].dt.strftime('%b')
df[['published_month']]
# Out:
#       published_month
# 0                 Jul
# 1                 Jun
# 2                 Sep
# 3                 Mar
# 4                 Dec
# ...               ...
# 37417             Feb
# 37418             Jan
# 37419             Jun
# 37420             Oct
# 37421             May
#
# [37422 rows x 1 columns]

# %% [markdown]
# 8. Find the number of videos published each month and arrange the months in a decreasing order based
# on the video count.

# %%
df.groupby("published_month").count().sort_values("view_count",ascending=False)
# Out:
#                  video_id  title  channel_id  channel_title  published_at  \
# published_month
# Oct                  4991   4991        4991           4991          4991
# Sep                  4880   4880        4880           4880          4880
# Nov                  4851   4851        4851           4851          4851
# Aug                  4262   4262        4262           4262          4262
# Dec                  3072   3072        3072           3072          3072
# Jul                  2340   2340        2340           2340          2340
# Jun                  2316   2316        2316           2316          2316
# Mar                  2258   2258        2258           2258          2258
# Feb                  2137   2137        2137           2137          2137
# Apr                  2126   2126        2126           2126          2126
# Jan                  2108   2108        2108           2108          2108
# ...

# %% [markdown]
# 9. Find the count of unique video_id, channel_id and channel_title.

# %%
df['video_id'].nunique()
# Out:
# 37422

# %%
df['channel_id'].nunique()
# Out:
# 10961

# %%
df['channel_title'].nunique()
# Out:
# 10883

# %% [markdown]
# 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10
# having lowest number of videos.

# %%
df.pivot_table(index='channel_title',values='video_id',aggfunc='count').sort_values('video_id',ascending=True).head(10)
# Out:
#                               video_id
# channel_title
#    SilverName                        1
# Mini Muka                            1
# Mini Ladd                            1
# MindYourLogic                        1
# Mind Body Tonic With Dr Sita         1
# Mimi Ar                              1
# Millyz                               1
# Milkair                              1
# Milissa Grande                       1
# MikuruSong                           1

# %%
df.pivot_table(index='channel_title',values='video_id',aggfunc='count').sort_values('video_id',ascending=True).tail(10)
# Out:
#                      video_id
# channel_title
# NHL                        86
# FORMULA 1                  87
# SSundee                    98
# SSSniperWolf               99
# WWE                       122
# NFL                       162
# NBA                       209
# BT Sport                  246
# The United Stand          301
# Sky Sports Football       533

# %% [markdown]
# 11. Find the title of the video which has the maximum number of likes and the title of the video having
# minimum likes and write your inferences.

# %%
df[df['likes']==df['likes'].max()][['title','likes']]
# Out:
#                                title     likes
# 26143  BTS () 'Dynamite' Official MV  31837675

# %%
df[df['likes']==df['likes'].min()][['title','likes']]
# Out:
#                                                    title  likes
# 18654  Kim Kardashian's Must-See Moments on "Saturday...      0

# %% [markdown]
# 12. Find the title of the video which has the maximum number of dislikes and the title of the video having
# minimum dislikes and write your inferences.

# %%
df[df['dislikes']==df['dislikes'].max()][['title','dislikes']]
# Out:
#                                      title  dislikes
# 13591  Cuties | Official Trailer | Netflix   2397733

# %%
df[df['dislikes']==df['dislikes'].min()][['title','dislikes']]
# Out:
#                                                    title  dislikes
# 18654  Kim Kardashian's Must-See Moments on "Saturday...         0

# %% [markdown]
# 13. Does the number of views have any effect on how many people disliked the video? Support your
# answer with a metric and a plot.

# %%
df1=df[['view_count','dislikes']]

# %%
df1.cov()
# Out:
#               view_count      dislikes
# view_count  5.888493e+14  5.100475e+11
# dislikes    5.100475e+11  9.429959e+08

# %%
df1.corr()
# Out:
#             view_count  dislikes
# view_count    1.000000  0.684469
# dislikes      0.684469  1.000000

# %%
import matplotlib.pyplot as plt
plt.scatter(df1['view_count'],df1['dislikes'])
plt.xlabel('view_count')
plt.ylabel('dislikes')
plt.title('view_count vs dislikes')
plt.show()

# %% [markdown]
# ## view_count has effects on the no.of dislikes. The coorelation is 0.6 and they are directly proportional to each other

# %% [markdown]
# 14. Display all the information about the videos that were published in January, and mention the count of
# videos that were published in January.

# %%
df[df['published_month']=="Jan"]
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
df[df['published_month']=="Jan"].count()['published_month']
# Out:
# 2108
